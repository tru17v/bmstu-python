# %% [markdown]
# <h1 style="text-align: center;">Jupyter Notebook в VS Code</h1>

# %% [markdown]
# ***Jupyter Notebook*** - текстовый редактор, особенность которого состоит в ячейках (cells), в которых можно выполнять фрагменты кода, а не целиком файл, что делает блокнот удобным инструментом для работы с данными. Можно установить JN непосредственно, а можно воспользоваться расширением для VS Code или других IDE.
#
# Далее скриншоты и описание идут для VS Code!
#
# Ячейки могут быть различных типов, среди которых мы будем в основном использовать лишь два:
# * Code - для набора кода, который python будет выполнять
# * Markdown - для набора и форматирования поясняющего текста, формул, изображений и т.д.
#
# Тип ячейки можно посмотреть в правом нижнем углу
#
# ![Тип ячейки](img\cell_type.png)
#
# Добавлять ячейки можно несколькими способами:
# * Кнопки в верхнем меню блокнота:
#
# ![Верхнее меню](img\jupyter_menu.png)
# * Кнопки под ячейкой:
#
# ![Нижнее меню](img\cell_menu.png)
#
# ---

# %% [markdown]
# <h1 style="text-align: center;">Разметка Markdown</h1>

# %% [markdown]
# ### Заголовки
#
# Существует 6 уровней заголовков, которые задаются с помощью символа ```#```.
#
# ```
# # Заголовок 1
# ## Заголовок 2
# ### Заголовок 3
# #### Заголовок 4
# ##### Заголовок 5
# ###### Заголовок 6
# ```
#
# Если же требуется вывести сам этот символ, следует воспользоваться командой ```\#```.
#
# Пример вывода:
#
# # Заголовок 1
# ## Заголовок 2
# ### Заголовок 3
# #### Заголовок 4
# ##### Заголовок 5
# ###### Заголовок 6
#
# ---

# %% [markdown]
# ### Курсив
#
# Задаётся с помощью звёздочки \* или символа нижнего подчёркивания \_ до и после выделяемого текста.
#
# ```
# *Курсив*
# _Курсив_
# ```
#
# Пример вывода:
#
# *Курсив*
# _Курсив_
#
# ---

# %% [markdown]
# ### Жирный текст
#
# Задаётся с помощью двух звёздочек \* или двух символов нижнего подчёркивания \_ до и после выделяемого текста.
#
# ```
# **Жирный текст**
# __Жирный текст__
# ```
#
# Пример вывода:
#
# **Жирный текст**
# __Жирный текст__
#
# ---

# %% [markdown]
# ### Жирный курсив
#
# Задаётся с помощью трёх звёздочек \* или трёх символов нижнего подчёркивания \_  до и после выделяемого текста.
#
# ```
# ***Жирный курсив***
# ___Жирный курсив___
# ```
#
# Пример вывода:
#
# ***Жирный курсив***
# ___Жирный курсив___
#
# ---

# %% [markdown]
# ### Зачёркнутый текст
#
# Задаётся с помощью двух тильд ~ до и после выделяемого текста.
#
# ```
# ~~Зачёркнутый текст~~
# ```
#
# Пример вывода:
#
# ~~Зачёркнутый текст~~
#
# ---

# %% [markdown]
# ### Текстовый блок
#
# Задаётся с помощью знака \> перед текстом.
#
# ```
# > Текстовый блок
# ```
#
# Пример вывода:
#
# > Текстовый блок
#
# Текстовые блоки могут быть различного уровня
#
# ```
# > Текстовый блок
# >> Ещё один текстовый блок
# >>> Ещё один текстовый блок
# ```
#
# Пример вывода:
#
# > Текстовый блок
# >> Ещё один текстовый блок
# >>> Ещё один текстовый блок
# ---

# %% [markdown]
# ### Горизонтальная линия
#
# Возможны варианты: три дефиса, три знака нижнего подчёркивания или три звёздочки.
#
# ```
# ---
# ___
# ***
# ```
#
# Пример вывода:
#
# ---
# ___
# ***

# %% [markdown]
# ### Нумерованные списки
#
# Для этого используется обычный ввод.
#
# ```
# 1. Мужество
# 2. Воля
# 3. Труд
# 4. Упорство
# ```
#
# Пример вывода:
#
# 1. Мужество
# 2. Воля
# 3. Труд
# 4. Упорство
#
# ---

# %% [markdown]
# ### Список с пунктами
#
# Используется символ дефиса перед пунктом.
#
# ```
# - Мужество
# - Воля
# - Труд
# - Упорство
# ```
#
# Пример вывода:
#
# - Мужество
# - Воля
# - Труд
# - Упорство
#
# ---

# %% [markdown]
# ### Гиперссылки
#
# Mardown понимает обычный ввод ссылок
#
# ```
# https://bmstu.ru
# ```
#
# Пример вывода:
#
# https://bmstu.ru
#
# Но можно оформить ссылку с текстом, для этого надо перед ссылкой указать текст в квадратных скобка, а саму ссылку взять в круглые скобки.
#
# ```
# [МГТУ им. Н.Э. Баумана](https://bmstu.ru)
# ```
#
# [МГТУ им. Н.Э. Баумана](https://bmstu.ru)
#
# ---

# %% [markdown]
# ### Таблицы
#
# Сначала задаётся строка заголовков столбцов
#
# ```
# |Столбец 1|Столбец 2|Столбец 3|Столбец 4|
# ```
#
# Потом строка, в которой задаётся выравнивание текста для каждого столбца.
#
# ```
# |---|:---|:---:|---:|
# ```
# Потом непосредственно информация, разделенная вертикальными чертами |.
#
# ```
# |А     |Б     |В     |Г     |
# |Д     |Е     |Ё     |Ж     |
# ```
# Итого полный вид:
#
# ```
# |Столбец 1|Столбец 2|Столбец 3|Столбец 4|
# |---|:---|:---:|---:|
# |А     |Б     |В     |Г     |
# |Д     |Е     |Ё     |Ж     |
# ```
#
# Пример вывода:
#
# |Столбец 1|Столбец 2|Столбец 3|Столбец 4|
# |---|:---|:---:|---:|
# |А     |Б     |В     |Г     |
# |Д     |Е     |Ё     |Ж     |
#
# ---

# %% [markdown]
# <h1 style="text-align: center;"> LaTeX </h1>

# %% [markdown]
# Markdown поддерживает ввод формул с помощью $\LaTeX$.
#
# Для этого необходимо заключить код формулы в значки "доллара"
# * \$<код формулы>\$ - для вывода inline
# * \$\$<код формулы>\$\$ - для вывода на отдельную строку
#
# ```
# $y_1=\sin(x)$
#
# $$y_2=\cos(x)$$
# ```
#
# Пример вывода:
#
# $y_1=\sin(x)$
#
# $$y_2=\cos(x)$$
#
# ---

# %% [markdown]
# ### Функции
#
# Следует помнить, что $sin(x)=s\cdot i\cdot \mathrm{n}(x)$, в то время, как функция синуса задаётся прямыми буквами $\sin(x)$.
#
# Для этого вместо `$sin(x)$` следует вводить `$\sin(x)$`. Если же вводимая функция нестандартная, в $\LaTeX$ можно задать свой собственный оператор или же использовать команду `\mathrm{}`.
#
# ```
# $\mathrm{Моя\_собственная\_функция}(x)$
# ```
#
# Пример вывода:
#
# $\mathrm{Моя\_собственная\_функция}(x)$
#
# ---

# %% [markdown]
# ### Греческие букквы
#
# ```
# $\alpha$
# $\Alpha$
# $\beta$
# $\Beta$
# $\gamma$
# $\Gamma$
# $\phi$
# $\varphi$
# $\Phi$
# ```
#
# Пример вывода:
#
# $\alpha$
# $\Alpha$
# $\beta$
# $\Beta$
# $\gamma$
# $\Gamma$
# $\phi$
# $\varphi$
# $\Phi$
#
# ---

# %% [markdown]
# ### Основные выражения
#
# - Индексы
#
# `$A_{1,2}^{3,4}$`
#
# $A_{1,2}^{3,4}$
#
# - Специальные символы
#
# `$\infty$ $\leftarrow$ $\|x\|$ $\vec{a}$ $\hat{b}$`
#
# $\infty$ $\leftarrow$ $\|x\|$ $\vec{a}$ $\hat{b}$
#
# - Дроби
#
# `$x=\frac{1}{2}$`
#
# $x=\frac{1}{2}$
#
# - Корни
#
# `$x=\sqrt{y}$`
#
# $x=\sqrt{y}$
#
# - Пределы
#
# `$e=\lim\limits_{x\rightarrow\infty}\left(1+\frac{1}{x}\right)^{x}$`
#
# $e=\lim\limits_{x\rightarrow\infty}\left(1+\frac{1}{x}\right)^{x}$
#
# - Интегралы
#
# `$\int\limits_{0}^{1}\cos^2(x)dx$`
#
# $\int\limits_{0}^{1}\cos^2(x)dx$
#
# ---

# %% [markdown]
# ### Скобки - в Markdown разницы не видно, но в пакетах $\LaTeX$ ещё как заметно
#
# Формулы должны быть читаемы, поэтому вместо
#
# $$\sin(\ln(\arctg(t)+1))$$
#
# лучше использовать скобки различной высоты, это просто сделать с помощью команд `\left(` и `\right)` вместо обычных скобок.
#
# $$\sin\left(\ln\left(\arctg\left(t\right)+1\right)\right)$$
#
# ---

# %% [markdown]
# <h1 style="text-align: center;"> HTML </h1>

# %% [markdown]
# Markdown поддерживает HTML разметку, что можно использовать, например, для вставки изображений
#
# ```
# <img src = ".\img\ulm.jpg" width = "100"/>
# <img src = ".\img\ulm.jpg" width = "300"/>
# ```
#
# Пример вывода:
#
# <img src = ".\img\ulm.jpg" width = "100"/>
# <img src = ".\img\ulm.jpg" width = "300"/>
